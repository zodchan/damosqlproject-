# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:D%40m0d%40r%40n123@localhost/test

# %%
# %%sql
# show tables;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %% [markdown]
# %%sql
# select * from Table_in_test;

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('de_project',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# create database gl_da_cloud;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 9 rows affected.
# [('de_project',),
#  ('gl_da_cloud',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use gl_da_cloud;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# drop database gl_da_cloud;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# show databases;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 8 rows affected.
# [('de_project',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
# %%sql
# use de_project;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table test (sno , name);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near ', name)' at line 1
# [SQL: create table test (sno , name);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# create table test_1(sno int , name varchar(100));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'test_1' already exists
# [SQL: create table test_1(sno int , name varchar(100));]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# select * from test_1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# insert into test_1 (sno,name) values (2, 'ajay');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# update test_1 set name='damo',sno=3  where sno=1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# delete from test_1 where sno=3
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# truncate table test_1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# drop table test_1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table employees( employee_id int primary key,
# first_name varchar(50) not null,
# last_name varchar(50) not null,
# hire_date date not null,
# salary decimal(10,2));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# select * from employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
#CTAS create table from another table as
# %%sql
create table high_paid_employee as
select 
      employee_id,
      first_name,
      last_name,
      salary,
from employees
where salary>60000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'from employees
# where salary>60000' at line 7
# [SQL: create table high_paid_employee as
# select
#       employee_id,
#       first_name,
#       last_name,
#       salary,
# from employees
# where salary>60000;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# insert into employees (employee_id,first_name,last_name,hire_date, salary)
# value (1,'sanju','P','25-02-26',40000);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# insert into employees (employee_id,first_name,last_name,hire_date, salary)
# value (2,'shashi','P','25-02-26',60000);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 'sanju', 'P', datetime.date(2025, 2, 26), Decimal('40000.00')),
#  (2, 'shashi', 'P', datetime.date(2025, 2, 26), Decimal('60000.00')),
#  (3, 'rajesh', 'P', datetime.date(2025, 2, 26), Decimal('70000.00'))]

# %%
# %%sql
# insert into employees (employee_id,first_name,last_name,hire_date, salary)
# value (3,'rajesh','P','25-02-26',70000);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# create table high_paid_employee as
# select
#       employee_id,
#       first_name,
#       last_name,
#       salary
# from employees
# where salary > 60000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from  high_paid_employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'test.high_paid_employees' doesn't exist
# [SQL: select * from  high_paid_employees;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# create temporary table temp_high_paid_employee(
#     employee_id int, salary decimal(10,2));
# insert into temp_high_paid_employees
# select employee_id, salary
# from employees
# where salary > 60000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'temp_high_paid_employee' already exists
# [SQL: create temporary table temp_high_paid_employee(
#     employee_id int, salary decimal(10,2));]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# drop table temp_high_paid_employee;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create temporary table temp_high_paid_employee(
#     employee_id int, salary decimal(10,2));
# insert into temp_high_paid_employees
# select employee_id, salary
# from employee
# where salary > 60000;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'temp_high_paid_employee' already exists
# [SQL: create temporary table temp_high_paid_employee(
#     employee_id int, salary decimal(10,2));]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# select * from high_paid_employee;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1146 (42S02): Table 'test.high_paid_employee' doesn't exist
# [SQL: select * from high_paid_employee;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# WITH: after using WITH if u have written program using SELECT this is known as CTE(common table expression) simialr to temprorary.
# %%sql

with high_salary_cte as ( 
    select 
employee_id, first_name, last_name, salary
from employees where salary > 70000)
create table high_salary_employee_via_cte
select* from high_salary_cte;
# Out:
#   Cell In[81], line 5
#     select
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# %%sql
# create table employees(employee_id int primary key, first_name varchar(50) not null,
# last_name varchar(50) not null,hire_date date not null,salary decimal(10,2));
# insert into employees (employee_id int primary key, first_name varchar(50) not null,
# last_name varchar(50) not null,hire_date date not null,salary decimal(10,2)) values (1,'damo','p','2025-03-02',60000), (2,'mamo','p','2025-03-02',60000);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'employees' already exists
# [SQL: create table employees(employee_id int primary key, first_name varchar(50) not null,
# last_name varchar(50) not null,hire_date date not null,salary decimal(10,2));]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# insert into employees (employee_id , first_name ,
# last_name,hire_date,salary) values (4,'damo','p','2025-03-02',60000), (5,'mamo','p','2025-03-02',60000);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# []

# %%
# %%sql
# drop table if exists employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table employees( employeeid int primary key, firstname varchar(50), lastname varchar(50)
#                       );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# describe employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('employeeid', 'int', 'NO', 'PRI', None, ''),
#  ('firstname', 'varchar(50)', 'YES', '', None, ''),
#  ('lastname', 'varchar(50)', 'YES', '', None, '')]

# %%
# %%sql
# alter table employees add email varchar(200);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc employees
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 4 rows affected.
# [('employeeid', 'int', 'NO', 'PRI', None, ''),
#  ('firstname', 'varchar(50)', 'YES', '', None, ''),
#  ('lastname', 'varchar(50)', 'YES', '', None, ''),
#  ('email', 'varchar(200)', 'YES', '', None, '')]

# %%
# %%sql
# alter table employees drop column lastname
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1091 (42000): Can't DROP 'lastname'; check that column/key exists
# [SQL: alter table employees drop column lastname]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# desc  employees;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('employeeid', 'int', 'NO', 'PRI', None, ''),
#  ('firstname', 'varchar(50)', 'YES', '', None, ''),
#  ('email', 'varchar(200)', 'YES', '', None, '')]

# %%
# %%sql
# alter table employees rename to emp_123;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc table emp_123;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(1, 'SIMPLE', 'emp_123', None, 'ALL', None, None, None, None, 1, 100.0, None)]

# %%
# %%sql
# desc emp_123;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('employeeid', 'int', 'NO', 'PRI', None, ''),
#  ('firstname', 'varchar(50)', 'YES', '', None, ''),
#  ('email', 'varchar(200)', 'YES', '', None, '')]

# %%
# %%sql
# create database uber;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.DatabaseError) 1007 (HY000): Can't create database 'uber'; database exists
# [SQL: create database uber;]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
# use uber;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table rides(
#     ride_id int,
#     driver_id int,
#     rider_id int,
#     pickup_location varchar(100),
#     dropoff_location varchar(100),
#     ride_date datetime,
#     fare decimal(10,2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'rides' already exists
# [SQL: create table rides(
#     ride_id int,
#     driver_id int,
#     rider_id int,
#     pickup_location varchar(100),
#     dropoff_location varchar(100),
#     ride_date datetime,
#     fare decimal(10,2)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (1,101,201,'chennai','coimbatore','2024-12-29 08:00:00',500),
# (2,102,202,'ahennai','aoimbatore','2024-12-29 08:00:00',800),
# (3,103,203,'bhennai','boimbatore','2024-12-29 08:00:00',900),
# (4,104,204,'dhennai','doimbatore','2024-12-29 08:00:00',100),
# (5,105,205,'ehennai','eoimbatore','2024-12-29 08:00:00',600);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 5 rows affected.
# []

# %%
# %%sql
# select * from uber.rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 10 rows affected.
# [(1, 101, 201, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00')),
#  (2, 102, 202, 'ahennai', 'aoimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('800.00')),
#  (3, 103, 203, 'bhennai', 'boimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('900.00')),
#  (4, 104, 204, 'dhennai', 'doimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('100.00')),
#  (5, 105, 205, 'ehennai', 'eoimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('600.00')),
#  (1, 101, 201, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00')),
#  (2, 102, 202, 'ahennai', 'aoimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('800.00')),
#  (3, 103, 203, 'bhennai', 'boimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('900.00')),
#  (4, 104, 204, 'dhennai', 'doimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('100.00')),
# ...

# %%
# %%sql
# select * from rides where fare > '500'and dropoff_location= 'eoimbatore'
# order by fare ;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(5, 105, 205, 'ehennai', 'eoimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('600.00')),
#  (5, 105, 205, 'ehennai', 'eoimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('600.00'))]

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('ride_id', 'int', 'YES', '', None, ''),
#  ('driver_id', 'int', 'YES', '', None, ''),
#  ('rider_id', 'int', 'YES', '', None, ''),
#  ('pickup_location', 'varchar(100)', 'YES', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'YES', '', None, ''),
#  ('ride_date', 'datetime', 'YES', '', None, ''),
#  ('fare', 'decimal(10,2)', 'YES', '', None, '')]

# %%
#constraints

# %%
# %%sql
# drop table rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table rides(
#     ride_id int primary key,
#     driver_id int,
#     rider_id int,
#     pickup_location varchar(100),
#     dropoff_location varchar(100),
#     ride_date datetime,
#     fare decimal(10,2)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1050 (42S01): Table 'rides' already exists
# [SQL: create table rides(
#     ride_id int primary key,
#     driver_id int,
#     rider_id int,
#     pickup_location varchar(100),
#     dropoff_location varchar(100),
#     ride_date datetime,
#     fare decimal(10,2)
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (2,101,201,'chennai','coimbatore','2024-12-29 08:00:00',500);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# drop table rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# create table rides(
#     ride_id int primary key ,
#     driver_id int  not null,
#     rider_id int not null,
#     pickup_location varchar(100) not null,
#     dropoff_location varchar(100)not null,
#     ride_date datetime not null,
#     fare decimal(10,2)not null
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (1,101,201,'chennai','coimbatore','2024-12-29 08:00:00',500);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '1' for key 'rides.PRIMARY'
# [SQL: insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (1,101,201,'chennai','coimbatore','2024-12-29 08:00:00',500);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 101, 201, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00')),
#  (2, 101, 201, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00'))]

# %%
# %%sql
# drop table rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
#composite primary key

# %%
# %%sql
# create table rides(
#     ride_id int  ,
#     driver_id int  not null,
#     rider_id int not null,
#     pickup_location varchar(100) not null,
#     dropoff_location varchar(100)not null,
#     ride_date datetime not null,
#     fare decimal(10,2)not null,
#     primary key (ride_id,rider_id)
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 7 rows affected.
# [('ride_id', 'int', 'NO', 'PRI', None, ''),
#  ('driver_id', 'int', 'NO', '', None, ''),
#  ('rider_id', 'int', 'NO', 'PRI', None, ''),
#  ('pickup_location', 'varchar(100)', 'NO', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'NO', '', None, ''),
#  ('ride_date', 'datetime', 'NO', '', None, ''),
#  ('fare', 'decimal(10,2)', 'NO', '', None, '')]

# %%
# %%sql
# insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (2,101,202,'chennai','coimbatore','2024-12-29 08:00:00',500);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(1, 101, 201, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00')),
#  (2, 101, 201, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00')),
#  (2, 101, 202, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00'))]

# %%
#unique constraints

# %%
# %%sql
# use uber;
#
# create table users(
#     user_id int primary key,
#     email varchar(100) unique
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# insert into users(user_id ,email)
# values(2, 'user2@example.com');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# insert into users(user_id ,email)
# values(3, null);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# insert into users(user_id ,email)
# values(null, abc@gmail.com);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.ProgrammingError) 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '@gmail.com)' at line 2
# [SQL: insert into users(user_id ,email)
# values(null, abc@gmail.com);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
# select * from users;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(3, None), (1, 'user1@example.com'), (2, 'user2@example.com')]

# %%
#not null constrains

# %%
# %%sql
# drop table rides;
# create table rides(
#     ride_id int primary key ,
#     driver_id int  not null,
#     rider_id int ,
#     pickup_location varchar(100) not null,
#     dropoff_location varchar(100)not null,
#     ride_date datetime not null,
#     fare decimal(10,2)not null
# );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (1,101,null,'karur','coimbatore','2024-12-29 08:00:00',500);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 101, None, 'karur', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00')),
#  (2, 101, None, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00'))]

# %%
#check constraints

# %%
# %%sql
# drop table rides;
# create table rides(
#     ride_id int primary key  ,
#     driver_id int  not null,
#     rider_id int not null,
#     pickup_location varchar(100) not null,
#     dropoff_location varchar(100)not null,
#     ride_date datetime not null,
#     fare decimal(10,2) check (fare>0));
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (2,101,201,'chennai','coimbatore','2024-12-29 08:00:00',-500);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.DatabaseError) 3819 (HY000): Check constraint 'rides_chk_1' is violated.
# [SQL: insert into rides (ride_id,driver_id,rider_id,pickup_location,dropoff_location, ride_date, fare)
# values
# (2,101,201,'chennai','coimbatore','2024-12-29 08:00:00',-500);]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# [(1, 101, 201, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 29, 8, 0), Decimal('500.00'))]

# %%
#foregin key constraints

# %%
# %%sql
# drop table if exists rides;
# drop table if exists drivers;
# create table drivers(
# driver_id int primary key,
# driver_name varchar(100),
# license_number varchar(50) unique
# );
#
# create table rides(
#   ride_id int primary key,
#   driver_id int,
#   pickup_location varchar (100),
#   dropoff_location varchar(100),
#   ride_date datetime,
#   fare decimal(10,2),
#   foreign key (driver_id) references drivers(driver_id)
#   );
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# desc drivers;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('driver_id', 'int', 'NO', 'PRI', None, ''),
#  ('driver_name', 'varchar(100)', 'YES', '', None, ''),
#  ('license_number', 'varchar(50)', 'YES', 'UNI', None, '')]

# %%
# %%sql
# desc rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 6 rows affected.
# [('ride_id', 'int', 'NO', 'PRI', None, ''),
#  ('driver_id', 'int', 'YES', 'MUL', None, ''),
#  ('pickup_location', 'varchar(100)', 'YES', '', None, ''),
#  ('dropoff_location', 'varchar(100)', 'YES', '', None, ''),
#  ('ride_date', 'datetime', 'YES', '', None, ''),
#  ('fare', 'decimal(10,2)', 'YES', '', None, '')]

# %%
# %%sql
# insert into drivers(driver_id, driver_name, license_number)
# values
# (101,'john doe','xyz12345'),
# (102,'jane smith','abc67890');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# []

# %%
# %%sql
# insert into rides(ride_id, driver_id, pickup_location, dropoff_location, ride_date,fare)
# values
# (301,101,'chennai','coimbatore','2024-12-01 08:00:00',500),
# (302,101,'chennai','madurai','2024-12-01 09:30:00',600),
# (303,102,'banglore','hyderabad','2024-12-01 10:00:00',700);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# []

# %%
# %%sql
# select * from drivers;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(101, 'john doe', 'xyz12345'), (102, 'jane smith', 'abc67890')]

# %%
# %%sql
# select * from rides;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [(301, 101, 'chennai', 'coimbatore', datetime.datetime(2024, 12, 1, 8, 0), Decimal('500.00'), 0),
#  (302, 101, 'chennai', 'madurai', datetime.datetime(2024, 12, 1, 9, 30), Decimal('600.00'), 0),
#  (303, 102, 'banglore', 'hyderabad', datetime.datetime(2024, 12, 1, 10, 0), Decimal('700.00'), 1)]

# %%
# %%sql
# alter table rides add column is_delete boolean default false;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# update rides set is_delete=true where driver_id=102
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# insert into rides(ride_id, driver_id, pickup_location, dropoff_location, ride_date,fare)
# values
# (304,999,'coimbatore','chennai','2024-12-03 10:00:00',800);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# (mysql.connector.errors.IntegrityError) 1452 (23000): Cannot add or update a child row: a foreign key constraint fails (`test`.`rides`, CONSTRAINT `rides_ibfk_1` FOREIGN KEY (`driver_id`) REFERENCES `drivers` (`driver_id`))
# [SQL: insert into rides(ride_id, driver_id, pickup_location, dropoff_location, ride_date,fare)
# values
# (304,999,'coimbatore','chennai','2024-12-03 10:00:00',800);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# %%sql
# delete from drivers where driver_id=101;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
# %%sql
# delete from rides where driver_id=102;

# %%
# %%sql
# create table demo1 (sno int, name varchar(100), country varchar (3) default 'ind');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 0 rows affected.
# []

# %%
# %%sql
# select * from demo1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 2 rows affected.
# [(1, 'gowtham', 'ind'), (2, 'gowtham', 'usa')]

# %%
# %%sql
# desc demo1;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 3 rows affected.
# [('sno', 'int', 'YES', '', None, ''),
#  ('name', 'varchar(100)', 'YES', '', None, ''),
#  ('country', 'varchar(3)', 'YES', '', 'ind', '')]

# %%
# %%sql
# insert into demo1(sno, name, country ) values (2, 'gowtham','usa');
# Out:
#  * mysql+mysqlconnector://root:***@localhost/test
# 1 rows affected.
# []

# %%
damo is very bad boy

# %%
gowtham is very good boy
